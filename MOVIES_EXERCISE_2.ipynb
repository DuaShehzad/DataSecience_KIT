# %%
import pandas as pd
import numpy as np

# %%
movies_data=pd.read_excel("/content/movies.xlsx")

# %%
movies_data.head(10)
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky        -2021
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves        -2021
# 5                          Outer Banks     (2020– )
# 6      The Last Letter from Your Lover        -2021
# 7                               Dexter  (2006–2013)
# 8                    Never Have I Ever     (2020– )
# 9                         Virgin River     (2019– )
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
# 5          \nAction, Crime, Drama                 7.6
# ...

# %%
movies_data.tail(5)
# Out:
#                  MOVIES      YEAR                                       GENRE  \
# 9993          Totenfrau  (2022– )               \nDrama, Thriller
# 9995             Arcane  (2021– )  \nAnimation, Action, Adventure
# 9996  Heart of Invictus  (2022– )            \nDocumentary, Sport
# 9997     The Imperfects  (2021– )     \nAdventure, Drama, Fantasy
# 9998     The Imperfects  (2021– )     \nAdventure, Drama, Fantasy
#
#       RATING        ONE-LINE  \
# 9993     NaN  \nAdd a Plot\n
# 9995     NaN  \nAdd a Plot\n
# 9996     NaN  \nAdd a Plot\n
# 9997     NaN  \nAdd a Plot\n
# 9998     NaN  \nAdd a Plot\n
#
#                                                   STARS  VOTES  RunTime  \
# 9993  \n    Director:\nNicolai Rohde\n| \n    Stars:...    NaN      NaN
# 9995                                                 \n    NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...    NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...    NaN      NaN
# ...

# %%
movies_data.shape

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MOVIES    9999 non-null   object
#  1   YEAR      9355 non-null   object
#  2   GENRE     9919 non-null   object
#  3   RATING    8179 non-null   float64
#  4   ONE-LINE  9999 non-null   object
#  5   STARS     9999 non-null   object
#  6   VOTES     8179 non-null   float64
#  7   RunTime   7041 non-null   float64
#  8   Gross     460 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 703.2+ KB

# %%
movies_data.describe()
# Out:
#             RATING         VOTES      RunTime
# count  8179.000000  8.179000e+03  7041.000000
# mean      6.921176  1.512406e+04    68.688539
# std       1.220232  7.005458e+04    47.258056
# min       1.100000  5.000000e+00     1.000000
# 25%       6.200000  1.660000e+02    36.000000
# 50%       7.100000  7.890000e+02    60.000000
# 75%       7.800000  3.772000e+03    95.000000
# max       9.900000  1.713028e+06   853.000000

# %%
movies_data=movies_data.drop_duplicates()

# %%
movies_data.shape
# Out:
# (9568, 9)

# %%
movies_data=movies_data.rename(columns=({'Gross':'Gross in $'}))

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9568 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MOVIES      9568 non-null   object
#  1   YEAR        9026 non-null   object
#  2   GENRE       9490 non-null   object
#  3   RATING      8168 non-null   float64
#  4   ONE-LINE    9568 non-null   object
#  5   STARS       9568 non-null   object
#  6   VOTES       8168 non-null   float64
#  7   RunTime     7008 non-null   float64
#  8   Gross in $  460 non-null    object
# dtypes: float64(3), object(6)
# memory usage: 747.5+ KB

# %%
movies_data['MOVIES']=movies_data['MOVIES'].str.strip()

# %%
movies_data.tail(5)
# Out:
#                  MOVIES      YEAR                                       GENRE  \
# 9993          Totenfrau  (2022– )               \nDrama, Thriller
# 9995             Arcane  (2021– )  \nAnimation, Action, Adventure
# 9996  Heart of Invictus  (2022– )            \nDocumentary, Sport
# 9997     The Imperfects  (2021– )     \nAdventure, Drama, Fantasy
# 9998     The Imperfects  (2021– )     \nAdventure, Drama, Fantasy
#
#       RATING        ONE-LINE  \
# 9993     NaN  \nAdd a Plot\n
# 9995     NaN  \nAdd a Plot\n
# 9996     NaN  \nAdd a Plot\n
# 9997     NaN  \nAdd a Plot\n
# 9998     NaN  \nAdd a Plot\n
#
#                                                   STARS  VOTES  RunTime  \
# 9993  \n    Director:\nNicolai Rohde\n| \n    Stars:...    NaN      NaN
# 9995                                                 \n    NaN      NaN
# 9996  \n    Director:\nOrlando von Einsiedel\n| \n  ...    NaN      NaN
# 9997  \n    Director:\nJovanka Vuckovic\n| \n    Sta...    NaN      NaN
# ...

# %%
movies_data.isnull().sum()
# Out:
# MOVIES          17
# YEAR           542
# GENRE           78
# RATING        1400
# ONE-LINE         0
# STARS            0
# VOTES         1400
# RunTime       2560
# Gross in $    9108
# dtype: int64

# %%
movies_data['VOTES']=movies_data['VOTES'].fillna('0')

# %%
movies_data['VOTES']=movies_data['VOTES'].str.replace(","," ")

# %%
movies_data['VOTES']=movies_data['VOTES'].astype(int)

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9568 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MOVIES      9551 non-null   object
#  1   YEAR        9026 non-null   object
#  2   GENRE       9490 non-null   object
#  3   RATING      8168 non-null   float64
#  4   ONE-LINE    9568 non-null   object
#  5   STARS       9568 non-null   object
#  6   VOTES       9568 non-null   int64
#  7   RunTime     7008 non-null   float64
#  8   Gross in $  460 non-null    object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 747.5+ KB

# %%
movies_data['RATING']=movies_data['RATING'].fillna(0.0)

# %%
movies_data.isnull().sum()
# Out:
# MOVIES          17
# YEAR           542
# GENRE           78
# RATING           0
# ONE-LINE         0
# STARS            0
# VOTES            0
# RunTime       2560
# Gross in $    9108
# dtype: int64

# %%
movies_data['GENRE']=movies_data['GENRE'].str.strip('\n')

# %%
movies_data.head(2)
# Out:
#                                 MOVIES      YEAR  \
# 0                        Blood Red Sky     -2021
# 1  Masters of the Universe: Revelation  (2021– )
#
#                                       GENRE  RATING  \
# 0      Action, Horror, Thriller                 6.1
# 1  Animation, Action, Adventure                 5.0
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
#
#                                                STARS  VOTES  RunTime  \
# 0  \n    Director:\nPeter Thorwarth\n| \n    Star...      0    121.0
# 1  \n            \n    Stars:\nChris Wood, \nSara...      0     25.0
#
#   Gross in $
# 0        NaN
# 1        NaN

# %%
movies_data['YEAR']=movies_data['YEAR'].str.strip()

# %%
movies_data['YEAR']=movies_data['YEAR'].str.replace('(','').str.replace(')','').str.replace('-','')
# Out:
# <ipython-input-51-f14f43e86f4a>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movies_data['YEAR']=movies_data['YEAR'].str.replace('(','').str.replace(')','').str.replace('-','')

# %%
movies_data.head(5)
# Out:
#                                 MOVIES               YEAR  \
# 0                        Blood Red Sky                NaN
# 1  Masters of the Universe: Revelation          2 0 2 1 –
# 2                     The Walking Dead  2 0 1 0 – 2 0 2 2
# 3                       Rick and Morty          2 0 1 3 –
# 4                      Army of Thieves                NaN
#
#                                       GENRE  RATING  \
# 0      Action, Horror, Thriller                 6.1
# 1  Animation, Action, Adventure                 5.0
# 2       Drama, Horror, Thriller                 8.2
# 3  Animation, Adventure, Comedy                 9.2
# 4         Action, Crime, Horror                 0.0
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
movies_data[['Type 1', 'Type 2', 'Type 3']] = movies_data['GENRE'].str.strip().str.split(',', 2, expand=True)
# Out:
# <ipython-input-64-e8c37715741d>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   movies_data[['Type 1', 'Type 2', 'Type 3']] = movies_data['GENRE'].str.strip().str.split(',', 2, expand=True)

# %%
print(movies_data['GENRE'].str.contains('\s').any())
# Out:
# True

# %%
movies_data.head(5)
# Out:
#                                 MOVIES               YEAR  \
# 0                        Blood Red Sky                NaN
# 1  Masters of the Universe: Revelation          2 0 2 1 –
# 2                     The Walking Dead  2 0 1 0 – 2 0 2 2
# 3                       Rick and Morty          2 0 1 3 –
# 4                      Army of Thieves                NaN
#
#                                       GENRE  RATING  \
# 0      Action, Horror, Thriller                 6.1
# 1  Animation, Action, Adventure                 5.0
# 2       Drama, Horror, Thriller                 8.2
# 3  Animation, Adventure, Comedy                 9.2
# 4         Action, Crime, Horror                 0.0
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
